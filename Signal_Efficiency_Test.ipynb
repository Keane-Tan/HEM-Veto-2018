EtaMin315 = np.array([14.516,9.459,11.650,17.333,12.719,12.130,11.612,11.362,11.126,11.241,11.486,10.650,10.706,10.481,10.295,10.610,10.112,10.247,10.579,10.799,13.749,9.998,10.125,11.259,11.086,7.117,9.167,11.768,9.663,10.279,10.912,9.414,10.114,11.263,9.921,8.722,11.392,10.400,11.332,12.413,12.916,9.929,13.591,12.709,14.093,13.830,10.679,10.844,10.626,10.469,10.945,10.391,10.824,10.597,10.613,10.797,10.361,10.200,10.669,10.845,10.334,12.500,25.000,10.526,11.765,6.522])
EtaMin3175 = np.array([17.742,13.514,13.592,18.000,13.596,13.314,12.568,12.114,12.121,11.938,12.136,11.585,11.583,11.370,10.981,11.438,11.159,11.149,11.435,11.608,14.862,10.847,10.821,12.305,11.858,7.825,9.974,12.578,10.481,11.151,11.732,10.282,10.810,11.908,10.573,9.337,12.152,11.200,12.226,13.451,13.887,10.681,14.709,13.761,15.150,14.883,11.529,11.791,11.470,11.373,11.709,11.293,11.758,11.642,11.298,11.707,11.167,10.981,11.720,11.769,11.178,12.500,25.000,10.526,11.765,10.870])

# %%
mpl.rc("font", family="serif", size=18)
plt.figure(figsize=(16,9))
ran = range(len(Best))
plt.plot(ran,Best,'bo-')
plt.plot(ran,Ori,'ro-')
print len(Best)
#plt.plot(ran,Pt26,'gX')
#plt.plot(ran,Pt27,'cX-')
#plt.plot(ran,Pt28,'mX')
#plt.plot(ran,Pt29,'yX-')
#plt.plot(ran,Pt30,'kX')
#plt.plot(ran,EtaMin305,'g^-')
#plt.plot(ran,EtaMin3075,'c^')
#plt.plot(ran,EtaMin310,'m^-')
#plt.plot(ran,EtaMin3125,'y^')
#plt.plot(ran,EtaMin315,'k^-')
#plt.plot(ran,EtaMin3175,'b^')
plt.axhline(y=np.mean(Best), color='b', linestyle=':')
plt.axhline(y=np.mean(Ori), color='r', linestyle=':')
plt.axvline(x=29, color='k', linestyle=':')
plt.ylabel("Percentage Removed")
plt.xlabel("Signal")
label = ['Best      : Pt = 25, $\eta_{min} = -3.2$','Original: Pt = 30, $\eta_{min} = -3.0$','Mean of Best','Mean of Original','Benchmark Signal: 3000_20_0.3_peak']
plt.legend(label,fontsize = 16, loc=0)
plt.show()
print np.mean(Best)
print np.mean(Ori)
print("Ratio of Mean (Best) to Mean (original): %4.3f" % (np.mean(Best)/np.mean(Ori)))
# Out:
# 66
# 13.022530303030301
# 5.056571212121213
# Ratio of Mean (Best) to Mean (original): 2.575

# %% [markdown]
# # Effect of Pt

# %%
mpl.rc("font", family="serif", size=18)
plt.figure(figsize=(16,9))
ran = range(len(Best))
plt.plot(ran,Best,'bo-')
plt.plot(ran,Ori,'ro-')
plt.plot(ran,Pt26,'gX-')
plt.plot(ran,Pt27,'cX-')
plt.plot(ran,Pt28,'mX-')
plt.plot(ran,Pt29,'yX-')
plt.plot(ran,Pt30,'kX-')
plt.ylabel("Percentage Removed")
plt.xlabel("Signal")
label = ['Best      : Pt = 25, $\eta_{min} = -3.2$','Original: Pt = 30, $\eta_{min} = -3.0$','Pt = 26','Pt = 27','Pt = 28','Pt = 29','Pt = 30']
plt.legend(label,loc=0, fontsize = 15, ncol = 2)
plt.show()

# %% [markdown]
# # Effect of $\eta$ and $\phi$

# %%
mpl.rc("font", family="serif", size=18)
plt.figure(figsize=(16,9))
ran = range(len(Best))
plt.plot(ran,Best,'bo-')
plt.plot(ran,Ori,'ro-')
plt.plot(ran,EtaMin305,'g^-')
plt.plot(ran,EtaMin3075,'c^-')
plt.plot(ran,EtaMin310,'m^-')
plt.plot(ran,EtaMin3125,'y^-')
plt.plot(ran,EtaMin315,'k^-')
plt.plot(ran,EtaMin3175,'^-',color = '#ff6600')
plt.ylabel("Percentage Removed")
plt.xlabel("Signal")
label = ['Best      : Pt = 25, $\eta_{min} = -3.2$','Original: Pt = 30, $\eta_{min} = -3.0$','$\eta_{min} = -3.05$','$\eta_{min} = -3.075$','$\eta_{min} = -3.1$',
         '$\eta_{min} = -3.125$','$\eta_{min} = -3.15$','$\eta_{min} = -3.175$']
plt.legend(label,loc=0,fontsize = 15, ncol = 2)
plt.show()

# %% [markdown]
# # Choosing Pt, $\eta$, $\phi$ that Affect Efficiency Less while Mitigating HEM

# %%
P27_E31 = np.array([11.290,9.459,9.709,14.000,8.772,8.876,9.153,8.126,8.729,8.898,9.222,8.089,7.780,7.830,7.903,7.744,7.709,7.962,8.110,8.309,10.809,7.755,7.594,8.567,8.685,4.952,7.028,8.836,7.270,7.883,8.324,7.166,7.656,8.871,7.406,6.511,7.595,8.800,8.611,9.826,10.125,7.533,10.407,9.984,10.701,10.679,7.878,8.133,8.137,7.911,8.238,7.821,8.239,7.950,7.938,8.442,7.861,7.783,7.991,8.162,7.673,0.000,20.000,5.263,11.765,4.348])
P30_E31 = np.array([11.290,9.459,8.738,12.000,7.895,7.396,7.514,7.374,7.734,7.505,8.066,7.012,6.695,6.941,6.728,6.692,6.745,6.888,7.006,6.961,9.696,6.718,6.528,7.521,7.254,4.376,5.930,7.632,6.302,6.793,7.194,6.098,6.501,7.724,6.102,6.020,6.835,7.200,7.488,8.338,8.704,6.593,8.956,8.697,9.412,9.281,6.853,7.052,7.047,6.853,7.128,6.675,7.055,6.768,6.872,7.390,6.759,6.666,6.907,7.117,6.581,0.000,15.000,5.263,11.765,4.348])

mpl.rc("font", family="serif", size=18)
plt.figure(figsize=(16,9))
ran = range(len(Best))
plt.plot(ran,Best,'bo-')
plt.plot(ran,Ori,'ro-')
plt.plot(ran,P27_E31,'g^-')
plt.plot(ran,P30_E31,'m^-')
plt.ylabel("Percentage Removed")
plt.xlabel("Signal")
label = ['Best      : Pt = 25, $\eta_{min} = -3.2$','Original: Pt = 30, $\eta_{min} = -3.0$',
         'Pt = 27, $\eta_{min} = -3.1$','Pt = 30, $\eta_{min} = -3.1$']
plt.legend(label,loc=0,fontsize = 15, ncol = 2)
plt.show()

print("Ratio of Mean (Best) to Mean (original): %4.3f" % (np.mean(Best)/np.mean(Ori)))
print("Ratio of Mean (Pt = 27, EtaMin = -3.1) to Mean (original): %4.3f" % (np.mean(P27_E31)/np.mean(Ori)))
print("Ratio of Mean (Pt = 30, EtaMin = -3.1) to Mean (original): %4.3f" % (np.mean(P30_E31)/np.mean(Ori)))
print np.mean(P30_E31)
# Out:
# Ratio of Mean (Best) to Mean (original): 2.575
# Ratio of Mean (Pt = 27, EtaMin = -3.1) to Mean (original): 1.674
# Ratio of Mean (Pt = 30, EtaMin = -3.1) to Mean (original): 1.458
# 7.37319696969697

# %% [markdown]
# # Vetos with Even Better Efficiency

# %%
P30_E302 = np.array([9.677,8.108,5.825,8.667,7.018,5.621,5.328,5.794,5.970,5.763,6.116,5.061,5.009,4.934,4.770,4.799,5.032,4.889,5.154,5.052,7.193,4.988,4.599,5.719,5.276,3.176,4.504,5.568,4.547,5.249,5.485,4.495,4.857,5.500,4.518,4.914,4.051,6.400,5.532,6.231,6.403,4.712,6.478,6.370,6.765,6.717,4.988,5.318,5.449,5.090,5.291,5.009,5.403,4.815,4.799,5.528,4.835,4.660,5.010,5.544,4.645,0.000,15.000,5.263,5.882,4.348])
P30_E305 = np.array([9.677,9.459,5.825,9.333,7.456,6.213,6.421,6.245,6.513,6.333,6.911,5.894,5.456,5.700,5.525,5.351,5.639,5.506,5.772,5.602,8.007,5.492,5.202,6.409,5.947,3.620,5.029,6.338,5.146,5.773,6.112,4.974,5.464,6.313,5.077,5.528,5.063,6.400,6.197,6.860,7.264,5.316,7.445,7.278,7.761,7.629,5.623,5.934,5.967,5.813,6.028,5.634,5.922,5.517,5.628,6.212,5.518,5.351,5.675,6.168,5.338,0.000,15.000,5.263,11.765,4.348])
P30_E307 = np.array([9.677,9.459,6.796,9.333,7.895,6.805,6.831,6.321,7.056,6.618,7.296,6.301,6.024,6.129,5.973,5.903,6.174,6.100,6.205,6.183,8.623,6.016,5.656,6.920,6.595,3.875,5.367,6.891,5.654,6.110,6.450,5.330,5.820,6.815,5.589,5.774,5.823,7.200,6.823,7.450,7.824,5.850,8.070,7.871,8.405,8.278,6.072,6.389,6.403,6.220,6.542,5.964,6.225,5.988,6.093,6.663,6.077,5.811,6.258,6.558,5.848,0.000,15.000,5.263,11.765,4.348])


mpl.rc("font", family="serif", size=18)
plt.figure(figsize=(16,10))
ran = range(len(Best))
plt.plot(ran,Ori,'bo-')
plt.plot(ran,P30_E302,'g^-')
plt.plot(ran,P30_E305,'c^-')
plt.plot(ran,P30_E307,'y^-')
plt.plot(ran,P30_E31,'m^-')
plt.plot(ran,Best,'r^-')
plt.ylabel("Percentage Removed")
plt.xlabel("Signal")
label = ['Original:   Pt = 30, $\eta_{min} = -3.0$','Pt = 30, $\eta_{min} = -3.02$',
         'Pt = 30, $\eta_{min} = -3.05$','Pt = 30, $\eta_{min} = -3.07$','Pt = 30, $\eta_{min} = -3.1$',
        'Best:   Pt = 25, $\eta_{min} = -3.2$']
plt.legend(label,loc=0,fontsize = 15, ncol = 2)
plt.show()
print np.mean(P30_E305)
print("Ratio of Mean (Best) to Mean (original): %4.3f" % (np.mean(Best)/np.mean(Ori)))
print("Ratio of Mean (Pt = 27, EtaMin = -3.1) to Mean (original): %4.3f" % (np.mean(P27_E31)/np.mean(Ori)))
print("Ratio of Mean (Pt = 30, EtaMin = -3.02) to Mean (original): %4.3f" % (np.mean(P30_E302)/np.mean(Ori)))
print("Ratio of Mean (Pt = 30, EtaMin = -3.05) to Mean (original): %4.3f" % (np.mean(P30_E305)/np.mean(Ori)))
print("Ratio of Mean (Pt = 30, EtaMin = -3.07) to Mean (original): %4.3f" % (np.mean(P30_E307)/np.mean(Ori)))
print("Ratio of Mean (Pt = 30, EtaMin = -3.1) to Mean (original): %4.3f" % (np.mean(P30_E31)/np.mean(Ori)))
print np.mean(P30_E31)
# Out:
# 6.229984848484849
# Ratio of Mean (Best) to Mean (original): 2.575
# Ratio of Mean (Pt = 27, EtaMin = -3.1) to Mean (original): 1.674
# Ratio of Mean (Pt = 30, EtaMin = -3.02) to Mean (original): 1.096
# Ratio of Mean (Pt = 30, EtaMin = -3.05) to Mean (original): 1.232
# Ratio of Mean (Pt = 30, EtaMin = -3.07) to Mean (original): 1.317
# Ratio of Mean (Pt = 30, EtaMin = -3.1) to Mean (original): 1.458
# 7.37319696969697

# %%
EtaLow = np.arange(-3.0,-3.305,-0.01)
EtaHigh = np.arange(-1.40,-1.09,0.01)
PhiLow = np.arange(-1.57,-1.88,-0.01)
PhiHigh = np.arange(-0.87,-0.56,0.01)

# %%
for i in range(len(EtaLow)):
    print("%4.3f< jet_i.Eta() <%4.3f and %4.3f< jet_i.Phi() <%4.3f" % (EtaLow[i],EtaHigh[i],PhiLow[i],PhiHigh[i]))
# Out:
# -3.000< jet_i.Eta() <-1.400 and -1.570< jet_i.Phi() <-0.870
# -3.010< jet_i.Eta() <-1.390 and -1.580< jet_i.Phi() <-0.860
# -3.020< jet_i.Eta() <-1.380 and -1.590< jet_i.Phi() <-0.850
# -3.030< jet_i.Eta() <-1.370 and -1.600< jet_i.Phi() <-0.840
# -3.040< jet_i.Eta() <-1.360 and -1.610< jet_i.Phi() <-0.830
# -3.050< jet_i.Eta() <-1.350 and -1.620< jet_i.Phi() <-0.820
# -3.060< jet_i.Eta() <-1.340 and -1.630< jet_i.Phi() <-0.810
# -3.070< jet_i.Eta() <-1.330 and -1.640< jet_i.Phi() <-0.800
# -3.080< jet_i.Eta() <-1.320 and -1.650< jet_i.Phi() <-0.790
# -3.090< jet_i.Eta() <-1.310 and -1.660< jet_i.Phi() <-0.780
# -3.100< jet_i.Eta() <-1.300 and -1.670< jet_i.Phi() <-0.770
# -3.110< jet_i.Eta() <-1.290 and -1.680< jet_i.Phi() <-0.760
# -3.120< jet_i.Eta() <-1.280 and -1.690< jet_i.Phi() <-0.750
# -3.130< jet_i.Eta() <-1.270 and -1.700< jet_i.Phi() <-0.740
# -3.140< jet_i.Eta() <-1.260 and -1.710< jet_i.Phi() <-0.730
# -3.150< jet_i.Eta() <-1.250 and -1.720< jet_i.Phi() <-0.720
# ...

# %%
EtaLow = np.arange(-3.0,-3.305,-0.01)[25:]
EtaHigh = np.arange(-1.40,-1.09,0.01)[25:]
PhiLow = np.arange(-1.57,-1.88,-0.01)[25:]
PhiHigh = np.arange(-0.87,-0.56,0.01)[25:]

# %%
print EtaLow
print EtaHigh
print PhiLow
print PhiHigh
# Out:
# [-3.25 -3.26 -3.27 -3.28 -3.29 -3.3 ]
# [-1.15 -1.14 -1.13 -1.12 -1.11 -1.1 ]
# [-1.82 -1.83 -1.84 -1.85 -1.86 -1.87]
# [-0.62 -0.61 -0.6  -0.59 -0.58 -0.57]
